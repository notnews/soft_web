# %%
import pandas as pd
from notnews import *
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\soodoku\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\soodoku\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df = pd.read_csv('../data/top10/current-output-top10.csv')

# %%
df.head()
# Out:
#          date      time             src      src_list  \
# 0  2016-07-10  02:22:16  washingtonpost  top-politics
# 1  2016-07-10  02:22:16  washingtonpost  top-politics
# 2  2016-07-10  02:22:16  washingtonpost  top-politics
# 3  2016-07-10  02:22:16  washingtonpost  top-politics
# 4  2016-07-10  02:22:16  washingtonpost  top-politics
#
#                                                  url  order  \
# 0  https://www.washingtonpost.com/news/post-polit...      1
# 1  https://www.washingtonpost.com/politics/with-a...      2
# 2  https://www.washingtonpost.com/news/post-polit...      3
# 3  https://www.washingtonpost.com/politics/in-ema...      4
# 4  https://www.washingtonpost.com/news/the-fix/wp...      5
#
#                                            link_text  \
# 0  A curveball in Trumps Veep search Hes seriousl...
# 1  With a hint of regret Obama describes new kind...
# 2  Democrats call for pathway to marijuana legali...
# 3  In email probe echoes of another time prosecut...
# ...

# %%
soft_news_url_cat_us(df, col = 'url')
# Out:
#              date      time             src          src_list  \
# 0      2016-07-10  02:22:16  washingtonpost      top-politics
# 1      2016-07-10  02:22:16  washingtonpost      top-politics
# 2      2016-07-10  02:22:16  washingtonpost      top-politics
# 3      2016-07-10  02:22:16  washingtonpost      top-politics
# 4      2016-07-10  02:22:16  washingtonpost      top-politics
# ...           ...       ...             ...               ...
# 40555  2016-11-08  13:02:46          google  mostpop-politics
# 40556  2016-11-08  13:02:46          google  mostpop-politics
# 40557  2016-11-08  13:02:46          google  mostpop-politics
# 40558  2016-11-08  13:02:46          google  mostpop-politics
# 40559  2016-11-08  13:02:46          google  mostpop-politics
#
#                                                      url  order  \
# 0      https://www.washingtonpost.com/news/post-polit...      1
# 1      https://www.washingtonpost.com/politics/with-a...      2
# ...

# %%
df.head()
# Out:
#          date      time             src      src_list  \
# 0  2016-07-10  02:22:16  washingtonpost  top-politics
# 1  2016-07-10  02:22:16  washingtonpost  top-politics
# 2  2016-07-10  02:22:16  washingtonpost  top-politics
# 3  2016-07-10  02:22:16  washingtonpost  top-politics
# 4  2016-07-10  02:22:16  washingtonpost  top-politics
#
#                                                  url  order  \
# 0  https://www.washingtonpost.com/news/post-polit...      1
# 1  https://www.washingtonpost.com/politics/with-a...      2
# 2  https://www.washingtonpost.com/news/post-polit...      3
# 3  https://www.washingtonpost.com/politics/in-ema...      4
# 4  https://www.washingtonpost.com/news/the-fix/wp...      5
#
#                                            link_text  \
# 0  A curveball in Trumps Veep search Hes seriousl...
# 1  With a hint of regret Obama describes new kind...
# 2  Democrats call for pathway to marijuana legali...
# 3  In email probe echoes of another time prosecut...
# ...

# %%
df[df.soft_lab.isnull() & df.hard_lab.isnull()].head()
# Out:
#           date      time             src             src_list  \
# 4   2016-07-10  02:22:16  washingtonpost         top-politics
# 5   2016-07-10  02:22:19  washingtonpost              themost
# 8   2016-07-10  02:22:19  washingtonpost              themost
# 9   2016-07-10  02:22:19  washingtonpost              themost
# 12  2016-07-10  02:22:30             nyt  mostviewed-national
#
#                                                   url  order  \
# 4   https://www.washingtonpost.com/news/the-fix/wp...      5
# 5     http://www.washingtonpost.com?tid=themost_title      6
# 8   https://www.washingtonpost.com/blogs/plum-line...      9
# 9   https://www.washingtonpost.com/news/morning-mi...     10
# 12  http://www.nytimes.com/2016/07/08/us/philando-...      3
#
#                                             link_text  \
# 4   Kevin Durants big announcement shined a bright...
# 5                                 The Washington Post
# 8   Trump just faced his first big leadership test...
# ...

# %%
df.to_csv("../data/top10/current-output-top10_soft.csv")

# %%
politics = pd.read_csv("../data/top10/current-output-politics-homepage.csv")

# %%
soft_news_url_cat_us(politics, col = 'url')
# Out:
#            date    time   src  order  \
# 0      20161107  130709  hpmg      1
# 1      20161107  130709  hpmg      2
# 2      20161107  130709  hpmg      3
# 3      20161107  130709  hpmg      4
# 4      20161107  130709  hpmg      5
# ...         ...     ...   ...    ...
# 66444  20161004  200928  wapo      7
# 66445  20161004  200928  wapo      8
# 66446  20161004  200928  wapo      9
# 66447  20161004  200928  wapo     10
# 66448  20161004  200928  wapo     11
#
#                                                      url  \
# 0      http://www.huffingtonpost.com/entry/matt-taibb...
# 1      http://www.huffingtonpost.com/entry/trump-penn...
# 2      http://www.huffingtonpost.com/entry/james-come...
# 3      http://www.huffingtonpost.com/entry/whats-it-l...
# 4      http://www.huffingtonpost.com/entry/solange-sa...
# ...                                                  ...
# 66444  https://www.washingtonpost.com/news/the-fix/wp...
# ...

# %%
politics.to_csv("../data/top10/current-output-politics-homepage_soft.csv")

# %%
homepage = pd.read_csv("../data/top10/current-output-homepage.csv")

# %%
soft_news_url_cat_us(homepage, col = 'url')
# Out:
#             date   time   src  order  \
# 0       20161107  50620  hpmg      1
# 1       20161107  50620  hpmg      2
# 2       20161107  50620  hpmg      3
# 3       20161107  50620  hpmg      4
# 4       20161107  50620  hpmg      5
# ...          ...    ...   ...    ...
# 312542  20160924  41225  wapo    119
# 312543  20160924  41225  wapo    120
# 312544  20160924  41225  wapo    121
# 312545  20160924  41225  wapo    122
# 312546  20160924  41225  wapo    123
#
#                                                       url  \
# 0       http://www.huffingtonpost.com/entry/beyonce-hi...
# 1       http://www.huffingtonpost.com/entry/homewrecki...
# 2       http://www.huffingtonpost.com/entry/anti-defam...
# 3       http://www.huffingtonpost.com/entry/hillary-cl...
# 4       http://www.huffingtonpost.com/entry/don-bendel...
# ...                                                   ...
# 312542  https://www.washingtonpost.com/news/in-sight/w...
# ...

# %%
homepage.to_csv("../data/top10/current-output-homepage_soft.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-eb2232731946> in <module>()
# ----> 1 homepage.to_csv("../data/top10/current-output-homepage_soft.csv")
#
# NameError: name 'homepage' is not defined

# %%
agg_2012 = pd.read_csv("../data/top10/agg_2012.csv", low_memory=False)

# %%
agg_2012.head()
# Out:
#      time   src  order                                                url  \
# 0  223037   wsj    NaN  http://web.archive.orghttp://online.wsj.com/ar...
# 1  162459   fox    NaN  http://web.archive.org/web/20120701162459/http...
# 2   32610  hpmg    NaN  http://web.archive.org/web/20120701032610/http...
# 3   50401   fox    NaN  http://web.archive.org/web/20120701050401/http...
# 4  155734   wsj    NaN  http://web.archive.org/web/20120701155734/http...
#
#                                            link_text  \
# 0               Germany Moves to Ratify Bailout Fund
# 1  GOP Rep. Rooney says health care repeal wont b...
# 2    Playing Fast and Furious With a Mans Reputation
# 3  Robert W. Merry Obamas legal victory political...
# 4                 HealthLaw Battle Enters Next Round
#
#                                    homepage_keywords path title text  \
# 0  personalization|business|sitewe|content|person...  NaN   NaN  NaN
# ...

# %%
soft_news_url_cat_us(agg_2012, col = 'url')
# Out:
#           time   src  order  \
# 0       223037   wsj    NaN
# 1       162459   fox    NaN
# 2        32610  hpmg    NaN
# 3        50401   fox    NaN
# 4       155734   wsj    NaN
# ...        ...   ...    ...
# 674011  162414   wsj    NaN
# 674012  225703   wsj    NaN
# 674013  225703   wsj    NaN
# 674014  235610   wsj    NaN
# 674015  235610   wsj    NaN
#
#                                                       url  \
# 0       http://web.archive.orghttp://online.wsj.com/ar...
# 1       http://web.archive.org/web/20120701162459/http...
# 2       http://web.archive.org/web/20120701032610/http...
# 3       http://web.archive.org/web/20120701050401/http...
# 4       http://web.archive.org/web/20120701155734/http...
# ...                                                   ...
# 674011  http://web.archive.org/web/20121106162414/http...
# 674012  http://web.archive.org/web/20121106225703/http...
# 674013  http://web.archive.org/web/20121106225703/http...
# ...

# %%
agg_2012.order.describe()
# Out:
# count    34045.000000
# mean         3.944162
# std          2.359996
# min          1.000000
# 25%          2.000000
# 50%          4.000000
# 75%          5.000000
# max         10.000000
# Name: order, dtype: float64

# %%
agg_2012.to_csv("../data/top10/agg_2012_soft.csv")

# %%
agg_2016 = pd.read_csv("../data/top10/agg_2016.csv", low_memory=False)

# %%
soft_news_url_cat_us(agg_2016, col = 'url')
# Out:
#           src  order                                                url  \
# 0         fox    NaN  http://www.foxnews.com/us/2016/07/29/2-san-die...
# 1         fox    NaN  http://www.foxbusiness.com/markets/2016/09/11/...
# 2         fox    NaN  http://www.foxbusiness.com/markets/2016/09/11/...
# 3         fox    NaN  http://www.foxnews.com/us/2016/09/22/1-charged...
# 4         fox    NaN  http://www.foxnews.com/world/2016/08/24/1-dead...
# ...       ...    ...                                                ...
# 400900  yahoo    NaN  https://www.yahoo.com/news/basementdwellers-th...
# 400901  yahoo    NaN  https://www.yahoo.com/news/basementdwellers-th...
# 400902  yahoo    NaN  https://www.yahoo.com/news/basementdwellers-th...
# 400903  yahoo    NaN  https://www.yahoo.com/news/basementdwellers-th...
# 400904  yahoo    NaN  https://www.yahoo.com/news/basementdwellers-th...
#
#                                                 link_text  \
# ...

# %%
agg_2016.to_csv("../data/top10/agg_2016_soft.csv")
