# %%
import pandas as pd
# !pip install notnews
from notnews import *
# Out:
# ...
#      |████████████████████████████████| 45.0 MB 7.0 kB/s
# ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
agg_2012 = pd.read_csv("/content/drive/MyDrive/data/media/top10/agg_2012.csv", low_memory=False)

# %%
agg_2012.head()
# Out:
#      time   src  order  ... unique       date     src2
# 0  223037   wsj    NaN  ...      0  01jul2012   wsj_IA
# 1  162459   fox    NaN  ...      1  01jul2012   fox_IA
# 2   32610  hpmg    NaN  ...      0  01jul2012  hpmg_IA
# 3   50401   fox    NaN  ...      0  01jul2012   fox_IA
# 4  155734   wsj    NaN  ...      0  01jul2012   wsj_IA
#
# [5 rows x 18 columns]

# %%
soft_news_url_cat_us(agg_2012, col = 'url')
agg_2012.head()
agg_2012.to_csv("/content/drive/MyDrive/data/media/top10/agg_2012_soft.csv")

# %%
agg_2016 = pd.read_csv("/content/drive/MyDrive/data/media/top10/agg_2016.csv", low_memory=False)

# %%
soft_news_url_cat_us(agg_2016, col = 'url')
agg_2016.head()
agg_2016.to_csv("/content/drive/MyDrive/data/media/top10/agg_2016_soft.csv")
